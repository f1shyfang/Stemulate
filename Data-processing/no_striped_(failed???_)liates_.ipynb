# %% [markdown]
# <a href="https://colab.research.google.com/github/f1shyfang/Stemulate/blob/Data-component/no_striped_(failed%3F%3F%3F_)liates_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/no dulpiates___.csv')

# %%
df.drop_duplicates(subset='text', keep='last', inplace=True)
print(df)

# %%
df['text'].is_unique
# Out:
# True

# %%
df['text'] = df['text'].str.strip("â€")

# %%
df['text'] = df['text'].str.replace('â', '')

# %%
df['text'] = df['text'].str.replace('€', '')

# %%
df.head(50)
# Out:
#     Unnamed: 0.1  Unnamed: 0               type  \
# 0              0           0             Footer
# 1              1           1  UncategorizedText
# 2              2           2  UncategorizedText
# 3              3           3              Title
# 4              4           4      NarrativeText
# 5              5           5  UncategorizedText
# 6              6           6      NarrativeText
# 7              7           7              Title
# 8              8           8              Title
# 9              9           9  UncategorizedText
# 10            10          10              Title
# 11            11          11              Title
# 12            12          12  UncategorizedText
# 13            13          13              Title
# 14            14          14              Title
# 15            15          15      NarrativeText
# 16            16          16      NarrativeText
# 17            17          17              Title
# ...

# %%
display(df)
# Out:
#         Unnamed: 0.1  Unnamed: 0               type  \
# 0                  0           0             Footer
# 1                  1           1  UncategorizedText
# 2                  2           2  UncategorizedText
# 3                  3           3              Title
# 4                  4           4      NarrativeText
# ...              ...         ...                ...
# 147103        147103      502948              Title
# 147104        147104      502950      NarrativeText
# 147105        147105      502951  UncategorizedText
# 147106        147106      502952      NarrativeText
# 147107        147107      502957      NarrativeText
#
#                               element_id  \
# 0       d6a4031733610bb080d0bfa794fcc9db
# 1       6c94e35ccc352d4e9ef0b99562cff995
# 2       3063aa7caf99f87bd040fbff695b1c73
# 3       da72bf5bbca4ca33b822955cfbbf9e5b
# 4       29ea6e4bd0ca2001300dd6b6e6b346a9
# ...                                  ...
# 147103  92f35f76f918877682e050bf23a29989
# ...

# %%
import re

pattern = r"adasdada"  # Define your regular expression pattern
rows_to_remove = df['text'].str.contains(pattern)
df_filtered = df[~rows_to_remove]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fa69b88b1970> in <cell line: 5>()
#       3 pattern = r"your_regex_pattern"  # Define your regular expression pattern
#       4 rows_to_remove = df['text'].str.contains(pattern)
# ----> 5 df_filtered = df[~rows_to_remove]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __invert__(self)
#    1459             return self.copy(deep=False)
#    1460
# -> 1461         new_data = self._mgr.apply(operator.invert)
#    1462         return self._constructor(new_data).__finalize__(self, method="__invert__")
#    1463
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     348
#     349             if callable(f):
# --> 350                 applied = b.apply(f, **kwargs)
#     351             else:
# ...

# %%
df.head(50)

# %%
df.to_csv('stripped????.csv')

# %% [markdown]
# doesnt work
